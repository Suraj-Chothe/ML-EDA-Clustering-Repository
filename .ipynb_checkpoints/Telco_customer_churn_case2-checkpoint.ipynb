# %% [markdown]
# # Telco_customer_churn_case2

# %% [markdown]
# Perform clustering analysis on the telecom data set. The data is a mixture of both categorical and numerical data. It consists of the number of customers who churn out. Derive insights and get possible information on factors that may affect the churn decision. Refer to Telco_customer_churn.xlsx dataset.
#
# This sample data module tracks a fictional telco company's customer churn based  on various internet services.The churn column indicates whether the customer departed within the last month. Other columns include gender, dependents, monthly charges, and many with information about the types of services each customer has.
# 1. Business Problem
# What is the business objective?
#
# Minimize:-
#
# Maximizes :-
#
# Are there any constraints?:-
#
# # this are column present in the data set
#
# Customer ID:- this is unique id ----> ordinal data ---->irrelevant
#
# Count:-
#
# Quarter:-
#
# Referred a Friend:-
#
# Number of Referrals:-
#
# Tenure in Months:-
#
# Offer:-
#
# Phone Service:-
#
# Avg Monthly Long Distance Charges:-
#
# Multiple Lines:-
#
# Internet Service:-
#
# Internet Type:-
#
# Avg Monthly GB Download:-
#
# Online Security:-
#
# Online Backup:-
#
# Device Protection Plan:-
#
# Premium Tech Support:-
#
# Streaming TV:-
#
# Streaming Movies:-
#
# Streaming Music:-
#
# Unlimited Data:-
#
# Contract:-
#
# Paperless Billing:-
#
# Payment Method:-
#
# Monthly Charge:-
#
# Total Charges:-
#
# Total Refunds:-
#
# Total Extra Data Charges:-
#
# Total Long Distance Charges:-
#
# Total Revenue:-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("C:/Data Science/data_set/Telco_customer_churn.xlsx")
data
# Out:
#      Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0     8779-QRDMV      1      Q3                No                    0
# 1     7495-OOKFY      1      Q3               Yes                    1
# 2     1658-BYGOY      1      Q3                No                    0
# 3     4598-XLKNJ      1      Q3               Yes                    1
# 4     4846-WHAFZ      1      Q3               Yes                    1
# ...          ...    ...     ...               ...                  ...
# 7038  2569-WGERO      1      Q3                No                    0
# 7039  6840-RESVB      1      Q3               Yes                    1
# 7040  2234-XADUH      1      Q3               Yes                    4
# 7041  4801-JZAZL      1      Q3               Yes                    1
# 7042  3186-AJIEK      1      Q3                No                    0
#
#       Tenure in Months    Offer Phone Service  \
# 0                    1     None            No
# ...

# %%
data.head(10)
# Out:
#   Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0  8779-QRDMV      1      Q3                No                    0
# 1  7495-OOKFY      1      Q3               Yes                    1
# 2  1658-BYGOY      1      Q3                No                    0
# 3  4598-XLKNJ      1      Q3               Yes                    1
# 4  4846-WHAFZ      1      Q3               Yes                    1
# 5  4412-YLTKF      1      Q3                No                    0
# 6  0390-DCFDQ      1      Q3               Yes                    1
# 7  3445-HXXGF      1      Q3               Yes                    6
# 8  2656-FMOKZ      1      Q3                No                    0
# 9  2070-FNEXE      1      Q3                No                    0
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 1     None            No                               0.00
# ...

# %%
# there are 7043 column are present and 30 column are present
data.shape
# Out:
# (7043, 30)

# %%
data.columns
# Out:
# Index(['Customer ID', 'Count', 'Quarter', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
# WE drop the unessacary column from the dataset 
#we can only place the data which is numerical  
data.drop(["Customer ID","Quarter","Referred a Friend","Phone Service","Multiple Lines","Offer","Phone Service","Multiple Lines","Internet Service","Internet Type","Online Security","Online Backup","Device Protection Plan",
       "Premium Tech Support", "Streaming TV","Streaming Movies",
       'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing'],axis=1, inplace= True)

# %%
data
# Out:
#       Count  Number of Referrals  Tenure in Months  \
# 0         1                    0                 1
# 1         1                    1                 8
# 2         1                    0                18
# 3         1                    1                25
# 4         1                    1                37
# ...     ...                  ...               ...
# 7038      1                    0                72
# 7039      1                    1                24
# 7040      1                    4                72
# 7041      1                    1                11
# 7042      1                    0                66
#
#       Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# 0                                  0.00                        8
# 1                                 48.85                       17
# 2                                 11.33                       52
# 3                                 19.76                       12
# ...

# %%
#7043 records are present and 
#after dropping the column 12 column are remain
data.shape
# Out:
# (7043, 12)

# %%
# there are 84516 data are present in the dataset including all the column
data.size
# Out:
# 84516

# %%
#checking the null value
a=data.isnull()
a.sum()
# Out:
# Count                                0
# Number of Referrals                  0
# Tenure in Months                     0
# Avg Monthly Long Distance Charges    0
# Avg Monthly GB Download              0
# Payment Method                       0
# Monthly Charge                       0
# Total Charges                        0
# Total Refunds                        0
# Total Extra Data Charges             0
# Total Long Distance Charges          0
# Total Revenue                        0
# dtype: int64

# %%
# drop the payment method column
data=data.drop(["Payment Method"], axis= 1)

# %%
#checkking the data type of each column
data.dtypes
# Out:
# Count                                  int64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Avg Monthly Long Distance Charges    float64
# Avg Monthly GB Download                int64
# Monthly Charge                       float64
# Total Charges                        float64
# Total Refunds                        float64
# Total Extra Data Charges               int64
# Total Long Distance Charges          float64
# Total Revenue                        float64
# dtype: object

# %%
#we are doing the type casting of the data
#type casting of the salaries is in float make it as int
#df.Avg Monthly Long Distance Charges=df.Avg Monthly Long Distance Charges.astype(int)
p={"Avg Monthly Long Distance Charges":int,
   "Monthly Charge":int,
   "Total Charges":int,
   "Total Refunds":int,
   "Total Long Distance Charges":int,
   "Total Long Distance Charges":int,"Total Revenue":int}
data=data.astype(p)

# %%
data.dtypes
# Out:
# Count                                int64
# Number of Referrals                  int64
# Tenure in Months                     int64
# Avg Monthly Long Distance Charges    int32
# Avg Monthly GB Download              int64
# Monthly Charge                       int32
# Total Charges                        int32
# Total Refunds                        int32
# Total Extra Data Charges             int64
# Total Long Distance Charges          int32
# Total Revenue                        int32
# dtype: object

# %%
#we are checking the null value after changing the data type into the int
a=data.isnull()
a.sum()
# Out:
# Count                                0
# Number of Referrals                  0
# Tenure in Months                     0
# Avg Monthly Long Distance Charges    0
# Avg Monthly GB Download              0
# Monthly Charge                       0
# Total Charges                        0
# Total Refunds                        0
# Total Extra Data Charges             0
# Total Long Distance Charges          0
# Total Revenue                        0
# dtype: int64

# %%
# we are taking the five number summary of the data
data.describe()
# Out:
#         Count  Number of Referrals  Tenure in Months  \
# count  7043.0          7043.000000       7043.000000
# mean      1.0             1.951867         32.386767
# std       0.0             3.001199         24.542061
# min       1.0             0.000000          1.000000
# 25%       1.0             0.000000          9.000000
# 50%       1.0             0.000000         29.000000
# 75%       1.0             3.000000         55.000000
# max       1.0            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        7043.000000              7043.000000
# mean                           22.514128                20.515405
# std                            15.371252                20.418940
# min                             0.000000                 0.000000
# 25%                             9.000000                 3.000000
# 50%                            22.000000                17.000000
# ...

# %%
#we are renaming the column
#data=df aslo put the variable name
data=data.rename({"Number of Referrals":"Number_of_Referrals",
"Tenure in Months":"Tenure_in_Months",
"Avg Monthly Long Distance Charges":"Avg_Monthly_Long_Distance_Charges",
"Avg Monthly GB Download":"Avg_Monthly_GB_Download",
"Monthly Charge":"Monthly_Charge",
"Total Charges":"Total_Charges",                    
"Total Refunds":"Total_Refunds",          
"Total Extra Data Charges":"Total_Extra_Data_Charges",
"Total Long Distance Charges":"Total_Long_Distance_Charges",
"Total Revenue":"Total_Revenue"},axis=1)

# %%
data.columns
# Out:
# Index(['Count', 'Number_of_Referrals', 'Tenure_in_Months',
#        'Avg_Monthly_Long_Distance_Charges', 'Avg_Monthly_GB_Download',
#        'Monthly_Charge', 'Total_Charges', 'Total_Refunds',
#        'Total_Extra_Data_Charges', 'Total_Long_Distance_Charges',
#        'Total_Revenue'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Count                                int64
# Number_of_Referrals                  int64
# Tenure_in_Months                     int64
# Avg_Monthly_Long_Distance_Charges    int32
# Avg_Monthly_GB_Download              int64
# Monthly_Charge                       int32
# Total_Charges                        int32
# Total_Refunds                        int32
# Total_Extra_Data_Charges             int64
# Total_Long_Distance_Charges          int32
# Total_Revenue                        int32
# dtype: object

# %%
#we can  draw the box-plot 
sns.boxplot(data.Number_of_Referrals)
#some outlier are present
# Out:
# <Axes: >

# %%
sns.boxplot(data.Tenure_in_Months)
# Out:
# <Axes: >

# %%
#incering the width of the box plot or any other bplot we use the following property
plt.rcParams['figure.figsize']=(30,8)
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
sns.boxplot(data.Count)
# Out:
# <Axes: >

# %%
sns.boxplot(data.Tenure_in_Months)
# Out:
# <Axes: >

# %% [markdown]
# we can see that in some columm there having the outlier so  make more perfect we use the scatter plot

# %%
sns.scatterplot(data.Count)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.scatterplot(data.Total_Revenue)
# Out:
# <Axes: ylabel='Total_Revenue'>

# %%
sns.scatterplot(data.Total_Charges)
# Out:
# <Axes: ylabel='Total_Charges'>

# %%
# we draw the hole colum histogram
sns.scatterplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
#  we can take the any inferance from the above data so we go for the histogram

# %%
#histogram
sns.histplot(data.)
# Out:
#   Cell In[32], line 2
#     sns.histplot(data.)
#                       ^
# SyntaxError: invalid syntax

# %%
sns.histplot(data.Total_Charges)
#the data is distributed righty

# %%
sns.histplot(data.Total_Long_Distance_Charges)
#the data is not the distrubeted normally . it is the right skewwed

# %%
sns.histplot(data.Total_Revenue)
# the data is not distrubuted normally. it is the right skewed data

# %%
#plt.rcParams['figure.figsize']=(12,6)
sns.histplot(data=data)

# %%
#finding the outlier
import seaborn as sns
sns.boxplot(data.Number_of_Referrals)
#there are outlier
# Out:
# <Axes: >

# %%
sns.boxplot(data.Total_Revenue)
# Out:
# <Axes: >

# %%
#we can calclaute the IQR for the Number_of_Referrals 
IQR=data.Number_of_Referrals.quantile(0.75)-data.Number_of_Referrals.quantile(0.25)
IQR
# Out:
# 3.0

# %%
lower_limit=data.Number_of_Referrals.quantile(0.25)-1.5*IQR    #make the lower limit value as 0 not the negative
lower_limit
# Out:
# -4.5

# %%
upper_limit=data.Number_of_Referrals.quantile(0.75)-1.5*IQR 
upper_limit
# Out:
# -1.5

# %%
#Winsorizer
#install the feature engine :- pip install feature_engine
from feature_engine.outliers import Winsorizer
winsor = Winsorizer(capping_method='iqr',
                    tail='both',
                    fold=1.5,
                    variables=['Number_of_Referrals']
                    )
#copy Winsorizer and paste in help tab of
#top right Windows , study the method

df_t=winsor.fit_transform(data[['Number_of_Referrals']])
sns.boxplot(data['Number_of_Referrals'])
# Out:
# <Axes: >

# %%
sns.boxplot(df_t['Number_of_Referrals'])
#all rhe outlier are remove from the NUmber_of_Referrals
# Out:
# <Axes: >

# %%
# we can remove all the outlier from the all the column

# %%
#trimming
import numpy as np
outliers_df=np.where(data.Balance>upper_limit,True,np.where(df.Balance<lower_limit,True,False))
#you can check outlier_df column in the varible explore
#floting the point number,if possible in varible explore
#now trimm that
df_trimmed=df.loc[~outliers_df]
df_trimmed      #it can show the trimmed element
df.shape        #without the trimed shape is
df_trimmed.shape        #we trimmed this elemnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # we can remove all the outlier from the all the column
# ----> 2 df =data.apply(lambda x: x(x > quant_df.loc[lower,x.name]) &
#       3                                 (x < quant_df.loc[upper,x.name]), axis=0)
#       4 #Winsorizer
#       5 #install the feature engine :- pip install feature_engine
#       6 from feature_engine.outliers import Winsorizer
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# ...

# %% [markdown]
# # modling of the data

# %%
#description of the dataframe 
data.describe()
# Out:
#         Count  Number_of_Referrals  Tenure_in_Months  \
# count  7043.0          7043.000000       7043.000000
# mean      1.0             1.951867         32.386767
# std       0.0             3.001199         24.542061
# min       1.0             0.000000          1.000000
# 25%       1.0             0.000000          9.000000
# 50%       1.0             0.000000         29.000000
# 75%       1.0             3.000000         55.000000
# max       1.0            11.000000         72.000000
#
#        Avg_Monthly_Long_Distance_Charges  Avg_Monthly_GB_Download  \
# count                        7043.000000              7043.000000
# mean                           22.514128                20.515405
# std                            15.371252                20.418940
# min                             0.000000                 0.000000
# 25%                             9.000000                 3.000000
# 50%                            22.000000                17.000000
# ...

# %%
# we can store the above description in the one varible
a=data.describe()

# %%
#there are scale differenece between the column value so we can remove that value from the 
#Dataframe by using the normalization  or standardizationso we can use the normalization
def norm_fun(i):
    x=(i-i.min())/(i.max()-i.min())
    return x
#now we can apply this noramlization function to df2 dataframe for all the rows and column from 1 until end
# since 0 th column has Universcity name hence skipped
df2= norm_fun(data.iloc[:,:])   #here we can use the data make it as noramlize that is in the 0 and 1 form and we can

# %%
# now we can descrine the df2 after we can make it in the normalize form
df2.describe()
# Out:
#        Count  Number_of_Referrals  Tenure_in_Months  \
# count    0.0          7043.000000       7043.000000
# mean     NaN             0.177442          0.442067
# std      NaN             0.272836          0.345663
# min      NaN             0.000000          0.000000
# 25%      NaN             0.000000          0.112676
# 50%      NaN             0.000000          0.394366
# 75%      NaN             0.272727          0.760563
# max      NaN             1.000000          1.000000
#
#        Avg_Monthly_Long_Distance_Charges  Avg_Monthly_GB_Download  \
# count                        7043.000000              7043.000000
# mean                            0.459472                 0.241358
# std                             0.313699                 0.240223
# min                             0.000000                 0.000000
# 25%                             0.183673                 0.035294
# 50%                             0.448980                 0.200000
# ...

# %%
a=df2.describe()

# %%
data=df2.drop("Count",axis=1)

# %%
data
# Out:
#       Number_of_Referrals  Tenure_in_Months  \
# 0                0.000000          0.000000
# 1                0.090909          0.098592
# 2                0.000000          0.239437
# 3                0.090909          0.338028
# 4                0.090909          0.507042
# ...                   ...               ...
# 7038             0.000000          1.000000
# 7039             0.090909          0.323944
# 7040             0.363636          1.000000
# 7041             0.090909          0.140845
# 7042             0.000000          0.915493
#
#       Avg_Monthly_Long_Distance_Charges  Avg_Monthly_GB_Download  \
# 0                              0.000000                 0.094118
# 1                              0.979592                 0.200000
# 2                              0.224490                 0.611765
# 3                              0.387755                 0.141176
# 4                              0.122449                 0.164706
# ...

# %%
#before you can applying the clustering you need to plot dendrogram first now to create the dendrogram , we need to measure distance
#we have import the linkage
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
#linkage function gives us hierarchical or aglomerative clustering ref the help for linkage
p=linkage(data,method="complete",metric="euclidean")
plt.figure(figsize=(16,8));
plt.title("Hierarchical Clustering Dendrogram");
plt.xlabel("phone");
plt.ylabel("internet_servise")
#ref help of dendogram sch.dendrogram
sch.dendrogram(p,leaf_rotation=0,leaf_font_size=10)
plt.show()

# %%
#dendrogram()
# now we can draw the dendgram
#applying  agglomertive clustering choosing 3 a clusters from dendrogram
#whatever has been dispalyed in dendrogram is not clustering
#it is just showing number of possible clusters
from sklearn.cluster import AgglomerativeClustering
dendo=AgglomerativeClustering(n_clusters=3,linkage='complete',affinity='euclidean').fit(data)
#apply labels to the cluster
dendo.labels_
cluster_labels=pd.Series(dendo.labels_)
#assign this series to df2 dataframe as column and name the column as 'cluster'
data['clust1']=cluster_labels
# Out:
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
data
# Out:
#       Number_of_Referrals  Tenure_in_Months  \
# 0                0.000000          0.000000
# 1                0.090909          0.098592
# 2                0.000000          0.239437
# 3                0.090909          0.338028
# 4                0.090909          0.507042
# ...                   ...               ...
# 7038             0.000000          1.000000
# 7039             0.090909          0.323944
# 7040             0.363636          1.000000
# 7041             0.090909          0.140845
# 7042             0.000000          0.915493
#
#       Avg_Monthly_Long_Distance_Charges  Avg_Monthly_GB_Download  \
# 0                              0.000000                 0.094118
# 1                              0.979592                 0.200000
# 2                              0.224490                 0.611765
# 3                              0.387755                 0.141176
# 4                              0.122449                 0.164706
# ...

# %%
########################################
data.shape
# Out:
# (7043, 11)

# %%
#we want to realocate th ecolumnn 7 to 0 th postion
df=data.iloc[:,[10,1,2,3,4,5,6,7,8,9]]#now check the Univ1 Dataframe

df.iloc[:,2:].groupby(df.clust1).mean()
#from the output cluster 2 has got highest top10 lowest accept ratio , best faculty ratio and highest expenses
#highest graduates ratio
# Out:
#         Avg_Monthly_Long_Distance_Charges  Avg_Monthly_GB_Download  \
# clust1
# 0                                0.583154                 0.209360
# 1                                0.536982                 0.294024
# 2                                0.411345                 0.228150
#
#         Monthly_Charge  Total_Charges  Total_Refunds  \
# clust1
# 0             0.300476       0.272555       0.121006
# 1             0.754253       0.654005       0.021969
# 2             0.387476       0.120406       0.031685
#
#         Total_Extra_Data_Charges  Total_Long_Distance_Charges  Total_Revenue
# clust1
# 0                       0.018937                     0.406904       0.318316
# 1                       0.068707                     0.452969       0.609522
# 2                       0.042136                     0.091287       0.114643

# %%
#######################
df.to_csv("telco_customer.csv",encoding="utf-8")
import os
os.getcwd()
#this file is created in  the working direcatory where we want to store 
# file as the working directory are shon on the above top most corner
######################################################################
# Out:
# 'C:\\Data Science\\7-clustering'

# %%
# now we can make the histogram of all the data point
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# now there are outlier are present so we can replace with by using the winsorization
